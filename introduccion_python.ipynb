# %% [markdown]
# <a href="https://colab.research.google.com/github/K3r1n24/PrograIII-2025/blob/main/introduccion_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo")
print("Bienvenidos hijosderemilputa a la maldita programacion computacional III")
# Out:
# Hola Mundo
# Bienvenidos hijosderemilputa a la maldita programacion computacional III

# %%
nombre = "Kerin De Paz"
edad = 20

print(nombre, edad)

edad = "veinte"
print("tu edad: ", edad)
# Out:
# Kerin De Paz 20
# tu edad:  veinte

# %%
num1 = 5
num2 = 8.9
suma = num1 + num2
print("La suma es: ", suma)
# Out:
# La suma es:  13.9

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
suma = num1 + num2
print("La suma es: ", suma)
# Out:
# Num1: 5
# Num2: 5
# La suma es:  10.0

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
resta = num1 - num2
print("La resta es: ", resta)
# Out:
# Num1: 10
# Num2: 6
# La resta es:  4.0
